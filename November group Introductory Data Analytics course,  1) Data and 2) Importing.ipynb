# %%
#I begin by importing the packages I will need and uploading a flat file csv of the data file I will be using
#This dataset contains details on athletes competing in Olympic games between 1896 and 2016, taken from the Kaggle website

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
os.getcwd()
Olympics= pd.read_csv("C:\\Users\\Jim/Downloads/athlete_events.csv/athlete_events.csv")

# %%
#I now pass the '.info()' command to give me some details on the dataset

# %%
Olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
#This dataset has 271116 data entries, which is a little big so I'm going to focus on swimming

# %%
swim= Olympics[Olympics['Sport'] == 'Swimming']

# %%
print(swim)
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 29          10   Einar Ferdinand "Einari" Aalto   M  26.0     NaN     NaN
# 35          15             Arvo Ossian Aaltonen   M  22.0     NaN     NaN
# 36          15             Arvo Ossian Aaltonen   M  22.0     NaN     NaN
# 37          15             Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15             Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# ...        ...                              ...  ..   ...     ...     ...
# 271012  135522  Klaas Erik "Klaas-Erik" Zwering   M  19.0   189.0    80.0
# 271013  135522  Klaas Erik "Klaas-Erik" Zwering   M  23.0   189.0    80.0
# 271038  135539            Marius Edmund Zwiller   M  18.0     NaN     NaN
# 271087  135556       Bogusaw Stanisaw Zychowicz   M  19.0   189.0    80.0
# 271088  135556       Bogusaw Stanisaw Zychowicz   M  19.0   189.0    80.0
#
#                Team  NOC        Games  Year  Season       City     Sport  \
# ...

# %%
#We now focus on the medal winners

# %%
Medals=['Gold', 'Silver', 'Bronze']; winner=swim['Medal'].isin(Medals); Swim_champ=swim[winner]; print(Swim_champ)
# Out:
#             ID                                   Name Sex   Age  Height  \
# 37          15                   Arvo Ossian Aaltonen   M  30.0     NaN
# 38          15                   Arvo Ossian Aaltonen   M  30.0     NaN
# 210        100                       Oszkr Abay-Nemes   M  22.0     NaN
# 476        259                             Reema Abdo   F  21.0   173.0
# 740        424                Moira Abernethy (-Ford)   F  17.0     NaN
# ...        ...                                    ...  ..   ...     ...
# 270530  135302                          Iris Zscherpe   F  17.0   174.0
# 270732  135396               Martijn Hendrik Zuijdweg   M  23.0   186.0
# 270773  135415                          Robertas ulpa   M  20.0   193.0
# 270939  135489  Anastasiya Valeryevna Zuyeva-Fesikova   F  22.0   182.0
# 271013  135522        Klaas Erik "Klaas-Erik" Zwering   M  23.0   189.0
#
#         Weight          Team  NOC        Games  Year  Season         City  \
# ...

# %%
#I also focus on the gold medal winners
gold= swim[swim['Medal'] == 'Gold']
print(gold.head())
# Out:
#         ID                       Name Sex   Age  Height  Weight  \
# 1772   980  Rebecca "Becky" Adlington   F  19.0   179.0    70.0
# 1773   980  Rebecca "Becky" Adlington   F  19.0   179.0    70.0
# 1843  1017     Nathan Ghar-Jun Adrian   M  19.0   198.0   100.0
# 1844  1017     Nathan Ghar-Jun Adrian   M  23.0   198.0   100.0
# 1846  1017     Nathan Ghar-Jun Adrian   M  23.0   198.0   100.0
#
#                Team  NOC        Games  Year  Season     City     Sport  \
# 1772  Great Britain  GBR  2008 Summer  2008  Summer  Beijing  Swimming
# 1773  Great Britain  GBR  2008 Summer  2008  Summer  Beijing  Swimming
# 1843  United States  USA  2008 Summer  2008  Summer  Beijing  Swimming
# 1844  United States  USA  2012 Summer  2012  Summer   London  Swimming
# 1846  United States  USA  2012 Summer  2012  Summer   London  Swimming
#
#                                               Event Medal
# 1772          Swimming Women's 400 metres Freestyle  Gold
# ...

# %%
elite.shape
# Out:
# (1099, 15)

# %%
# To check that the countries showing up in this dataset correspond with known info on countries with winning swim teams
# I do this by retrieving data from a website on the subject

import requests
from bs4 import BeautifulSoup

url = 'https://www.worldatlas.com/articles/countries-producing-the-best-competitive-swimmers.html'

r = requests.get(url)

html_doc = r.text

soup= BeautifulSoup(html_doc)

swim_title= soup.title

print(swim_title)

swim_text= soup.get_text()

print(swim_text)
# Out:
# <title>Countries Producing The Best Competitive Swimmers - WorldAtlas</title>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Countries Producing The Best Competitive Swimmers - WorldAtlas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Countries Producing The Best Competitive Swimmers
#
#
#
#
#
#
#
#
# A professional swimmer.
#
#
#
#
#
#
#
# ...

# %%
#I also download another csv file on powerlifting, to compare the athletes of these sports with swimmers later

# %%
#To do this I download straight from the web rather than importing a downloaded flat file

# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
# Downloading this file required a Kaggle username and passcode downloaded from my homepage on the site as a token
dataset= 'https://www.kaggle.com/datasets/open-powerlifting/powerlifting-database'
od.download(dataset)
# Out:
# Skipping, found downloaded files in ".\powerlifting-database" (use force=True to force download)

# %%
# This command originally saved the csv file into a folder on my Jupyter Homepage, so I had to move the file to the homepage
# So that the csv file could be read
import os
data_dir='.\powerlifting-database'

# %%
os.listdir(data_dir)
# Out:
# ['.ipynb_checkpoints']

# %%
powerlifting= pd.read_csv('openpowerlifting.csv')
# Out:
# C:\Users\Jim\anacondaforjupiter\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
powerlifting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1423354 entries, 0 to 1423353
# Data columns (total 37 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Name             1423354 non-null  object
#  1   Sex              1423354 non-null  object
#  2   Event            1423354 non-null  object
#  3   Equipment        1423354 non-null  object
#  4   Age              757527 non-null   float64
#  5   AgeClass         786800 non-null   object
#  6   Division         1415176 non-null  object
#  7   BodyweightKg     1406622 non-null  float64
#  8   WeightClassKg    1410042 non-null  object
#  9   Squat1Kg         337580 non-null   float64
#  10  Squat2Kg         333349 non-null   float64
#  11  Squat3Kg         323842 non-null   float64
#  12  Squat4Kg         3696 non-null     float64
#  13  Best3SquatKg     1031450 non-null  float64
#  14  Bench1Kg         499779 non-null   float64
# ...
